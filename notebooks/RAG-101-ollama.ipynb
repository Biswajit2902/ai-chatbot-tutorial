# %%
import requests  # Used for making HTTP requests, essential for interacting with APIs and web services.
import json      # Provides methods for serializing and deserializing JSON data, often used for API request/response handling.
import os        # Provides a way to interact with the operating system, useful for file path management, environment variables, etc.
import time      # Includes functions for time-related operations, such as delays, sleep, and measuring time intervals.

import pandas as pd  # Imports pandas for data manipulation and analysis, often used to read, process, and transform data in tabular formats.

# Import a specific class for loading PDF documents, allowing easy extraction of text from PDF files.
from langchain.document_loaders import UnstructuredPDFLoader  

# Imports a text splitter for breaking down text documents into smaller, manageable chunks for processing, 
# especially useful in natural language processing or document retrieval tasks.
from langchain_text_splitters import RecursiveCharacterTextSplitter  

import chromadb  # Imports ChromaDB, a database specifically designed for managing embeddings, useful for retrieval-based AI applications.

# Imports a specific error class from ChromaDB to handle exceptions when working with collections that may not exist.
from chromadb.errors import InvalidCollectionException

# %%
# Function to initialize a ChromaDB client with a persistent storage directory
def get_chroma_client():
    # Define the directory where ChromaDB data will be stored
    persist_dir = os.path.join(os.getcwd(), "chromadb_data")  
    os.makedirs(persist_dir, exist_ok=True)  # Create the directory if it does not exist
    # Initialize and return a persistent ChromaDB client, with data saved to persist_dir
    return chromadb.PersistentClient(path=persist_dir)  

# Helper function to split lists into smaller chunks
def chunk_list(lst, chunk_size):
    """
    Split a list into smaller chunks of specified size.

    Parameters:
    - lst (list): The list to be split.
    - chunk_size (int): The maximum size of each chunk.

    Returns:
    - list: A list of chunks, each a sublist of the original list.
    """
    return [lst[i:i + chunk_size] for i in range(0, len(lst), chunk_size)]

# EmbeddingAPI class to handle text embedding requests via an external API
class EmbeddingAPI:
    def __init__(self, url: str, model: str):
        """
        Initializes the EmbeddingAPI with the specified endpoint and model.

        Parameters:
        - url (str): The API endpoint URL for embedding requests.
        - model (str): The model identifier to specify which embedding model to use.
        """
        self.url = url  # URL of the embedding API
        self.model = model  # Embedding model name
        self.headers = {
            'Content-Type': 'application/json'  # Sets request headers for JSON payloads
        }
    
    def encode(self, input_text: str):
        """
        Sends a request to the embedding API to generate embeddings for the input text.

        Parameters:
        - input_text (str): The text to encode into embeddings.

        Returns:
        - tuple: A tuple containing the full result and the embeddings list.
        """
        # Construct the payload in JSON format
        payload = json.dumps({
            "model": self.model,
            "input": input_text
        })
        
        try:
            # Send a POST request to the API with headers and payload
            response = requests.post(self.url, headers=self.headers, data=payload)
            response.raise_for_status()  # Raises an error if the request was unsuccessful
            result = response.json()  # Parse JSON response
            return result, result["embeddings"]  # Return both the full response and embeddings
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")
            return None, []  # Return empty embeddings on error

# ChatAssistant class to handle chat response generation using an external API
class ChatAssistant:
    def __init__(self, url: str, model: str):
        """
        Initializes the ChatAssistant with the specified chat model API endpoint.

        Parameters:
        - url (str): The endpoint URL for the chat API.
        - model (str): Model identifier for generating chat responses.
        """
        self.url = url  # API endpoint for chat model requests
        self.model = model  # Chat model name
        self.headers = {"Content-Type": "application/json"}

    def get_chat_response(self, query: str, retrieved_docs: str) -> str:
        """
        Generates a response from the chat model based on a user query and retrieved document context.

        Parameters:
        - query (str): The user's question.
        - retrieved_docs (str): Context or content from documents to aid in answering the query.

        Returns:
        - str: The model's response text, or None if an error occurs.
        """
        # Define the system prompt, instructing the assistant to use only the provided context
        system_prompt = f"""You are an intelligent assistant that helps users understand documents. 
        Base your responses solely on the provided context. If the context doesn't contain enough 
        information to answer the question, say so clearly. Keep responses concise and relevant.
        Do not generate information outside of the provided context.

        Context: {retrieved_docs}
        """
        
        # Construct the payload for the API request with system and user messages
        payload = {
            "model": self.model,
            "option": {"temperature": 0.7},  # Set temperature for controlled response variability
            "messages": [
                {
                    "role": "system",
                    "content": system_prompt
                },
                {
                    "role": "user",
                    "content": f"Answer the following query using only the given context. Query: '{query}'."
                }
            ]
        }

        try:
            # Send request to the chat API and parse response
            response = requests.post(self.url, json=payload, headers=self.headers)
            response.raise_for_status()  # Raises an error for unsuccessful requests
            return response.json()["choices"][0]["message"]["content"]  # Extract and return response content
        except requests.exceptions.RequestException as e:
            print(f"An error occurred: {e}")
            return None  # Return None if request fails

# RAG (Retrieval-Augmented Generation) class to manage document retrieval and response generation
class RAG:
    def __init__(self):
        """
        Initializes the RAG class, setting up clients for embedding and chat models
        and initializing a vector database collection.
        """
        self.vector_db_client = get_chroma_client()  # Initialize ChromaDB client for vector storage
        self.embedding_model = EmbeddingAPI(url="http://localhost:11434/api/embed", model="llama3.2:1b")  # Embedding model
        self.chat_assistant = ChatAssistant(url="http://localhost:11434/v1/chat/completions/", model="llama3.2:1b")  # Chat assistant
        self.init_collection()  # Initialize or retrieve a vector collection in ChromaDB

    def init_collection(self):
        """Initializes a collection in ChromaDB if it doesn't already exist."""
        try:
            self.collection = self.vector_db_client.get_collection(name="rag")  # Retrieve the collection
        except InvalidCollectionException:
            # Create collection if it does not exist, setting metadata for similarity search
            self.collection = self.vector_db_client.create_collection(
                name="rag",
                metadata={"hnsw:space": "cosine"}
            )

    def validate_xlsx(self, df):
        """
        Validates that the DataFrame has the required columns for processing.

        Parameters:
        - df (DataFrame): The DataFrame to validate.

        Returns:
        - bool: True if valid, False otherwise.
        """
        required_columns = {'question', 'answer'}
        return all(col in df.columns for col in required_columns)  # Check for necessary columns

    def load_and_process_xlsx(self, filepath):
        """Loads and processes an Excel file containing question-answer pairs for embedding."""
        try:
            df = pd.read_excel(filepath)  # Load Excel file
            
            if not self.validate_xlsx(df):  # Validate columns
                print("Excel file must contain 'question' and 'answer' columns")
                return None
            
            # Process each row into a dictionary containing QA pairs
            chunks = []
            for idx, row in df.iterrows():
                qa_text = f"Question: {row['question']}\nAnswer: {row['answer']}"
                chunks.append({
                    "source": "xlsx",
                    "page": idx,
                    "chunk_idx": 0,
                    "text": qa_text,
                    "question": row['question'],
                    "answer": row['answer']
                })
            
            return chunks  # Return processed chunks
        except Exception as e:
            print(f"Error processing Excel file: {str(e)}")
            return None

    def load_and_process_pdf(self, pdf_path):
        """Loads and processes text content from a PDF, returning document chunks for embedding."""
        try:
            loader = UnstructuredPDFLoader(file_path=pdf_path)  # Load PDF
            documents = loader.load()
            
            # Process each page into chunks
            chunks = []
            for i, doc in enumerate(documents):
                doc_chunks = self.chunk_text(doc.page_content)  # Split page content into chunks
                for chunk_idx, chunk in enumerate(doc_chunks):
                    chunks.append({
                        "source": doc.metadata.get('source', 'unknown'),
                        "page": i,
                        "chunk_idx": chunk_idx,
                        "text": chunk
                    })
            
            return chunks  # Return document chunks
        except Exception as e:
            print(f"Error processing PDF: {str(e)}")
            return None

    def chunk_text(self, content):
        """
        Splits a long text into smaller overlapping chunks using RecursiveCharacterTextSplitter.

        Parameters:
        - content (str): The text content to split.

        Returns:
        - list: A list of text chunks.
        """
        text_splitter = RecursiveCharacterTextSplitter(
            chunk_size=1000,  # Size of each chunk
            chunk_overlap=200,  # Overlap between chunks to preserve context
            length_function=len,
            is_separator_regex=False
        )
        return text_splitter.split_text(content)  # Split and return chunks

    def get_embeddings_in_chunks(self, texts, chunk_size=20):
        """
        Encodes a list of texts into embeddings in batches.

        Parameters:
        - texts (list): The list of texts to encode.
        - chunk_size (int): Batch size for embedding requests.

        Returns:
        - list: A list of embeddings.
        """
        try:
            embeds = []
            for chunk in chunk_list(texts, chunk_size):  # Process texts in smaller batches
                _, embeddings = self.embedding_model.encode(chunk)  # Get embeddings for the batch
                embeds.extend(embeddings)  # Add embeddings to the list
            return embeds
        except Exception as e:
            print(f"Error generating embeddings: {str(e)}")
            return None

    def add_to_chromadb(self, chunks):
        """
        Adds processed chunks to the ChromaDB collection with embeddings.

        Parameters:
        - chunks (list): A list of document chunks, each containing text and metadata.

        Returns:
        - bool: True if successful, False otherwise.
        """
        try:
            batch_size = 100  # Set the batch size for ChromaDB operations
            for i in range(0, len(chunks), batch_size):
                batch = chunks[i:i + batch_size]
                
                # Generate IDs and texts, and retrieve embeddings
                ids = [f"{chunk['page']}_{chunk['chunk_idx']}" for chunk in batch]
                texts = [chunk["text"] for chunk in batch]
                embeddings = self.get_embeddings_in_chunks(texts)
                
                if embeddings:
                    # Add documents, metadata, and embeddings to the collection
                    self.collection.add(
                        documents=texts,
                        metadatas=batch,
                        embeddings=embeddings,
                        ids=ids
                    )
            return True
        except Exception as e:
            print(f"Error adding to ChromaDB: {str(e)}")
            return False

    def search_document(self, query):
        """
        Searches for the most relevant documents based on the query embedding.

        Parameters:
        - query (str): The search query string.

        Returns:
        - list or None: A list of matching results, or None if an error occurs.
        """
        try:
            _, embedding = self.embedding_model.encode(query)  # Generate embedding for query
            results = self.collection.query(
                query_embeddings=embedding,
                n_results=5,  # Number of top results to return
                include=["documents", "metadatas", "distances"]
            )
            return results  # Return search results
        except Exception as e:
            print(f"Error searching ChromaDB: {str(e)}")
            return None

    def delete_collection(self):
        """Deletes the 'rag' collection from ChromaDB to clean up or reset."""
        self.vector_db_client.delete_collection("rag")  # Delete the collection if it exists

# %%
rag_agent = RAG()

# %%
pdf_path = "../docs/Transformers.pdf"
# Load and process the PDF
documents = rag_agent.load_and_process_pdf(pdf_path)

# %%
rag_agent.add_to_chromadb(documents)
# Out:
# Add of existing embedding ID: 0_0
# Add of existing embedding ID: 0_1
# Add of existing embedding ID: 0_2
# Add of existing embedding ID: 0_3
# Add of existing embedding ID: 0_4
# Add of existing embedding ID: 0_5
# Add of existing embedding ID: 0_6
# Add of existing embedding ID: 0_7
# Add of existing embedding ID: 0_8
# Add of existing embedding ID: 0_9
# Add of existing embedding ID: 0_10
# Add of existing embedding ID: 0_11
# Add of existing embedding ID: 0_12
# Add of existing embedding ID: 0_13
# Add of existing embedding ID: 0_14
# Add of existing embedding ID: 0_15
# Add of existing embedding ID: 0_16
# Add of existing embedding ID: 0_17
# Add of existing embedding ID: 0_18
# Add of existing embedding ID: 0_19
# Add of existing embedding ID: 0_20
# Add of existing embedding ID: 0_21
# Add of existing embedding ID: 0_22
# Add of existing embedding ID: 0_23
# Add of existing embedding ID: 0_24
# Add of existing embedding ID: 0_25
# Add of existing embedding ID: 0_26
# Add of existing embedding ID: 0_27
# Add of existing embedding ID: 0_28
# Add of existing embedding ID: 0_29
# Add of existing embedding ID: 0_30
# Add of existing embedding ID: 0_31
# Add of existing embedding ID: 0_32
# Add of existing embedding ID: 0_33
# Add of existing embedding ID: 0_34
# Add of existing embedding ID: 0_35
# Add of existing embedding ID: 0_36
# Add of existing embedding ID: 0_37
# Add of existing embedding ID: 0_38
# Add of existing embedding ID: 0_39
# Add of existing embedding ID: 0_40
# Add of existing embedding ID: 0_41
# Add of existing embedding ID: 0_42
# Add of existing embedding ID: 0_43
# Add of existing embedding ID: 0_44
# Add of existing embedding ID: 0_45
# Add of existing embedding ID: 0_46
# Add of existing embedding ID: 0_47
# Add of existing embedding ID: 0_48
# Add of existing embedding ID: 0_49
# Add of existing embedding ID: 0_50
# Insert of existing embedding ID: 0_0
# Insert of existing embedding ID: 0_1
# Insert of existing embedding ID: 0_2
# Insert of existing embedding ID: 0_3
# Insert of existing embedding ID: 0_4
# Insert of existing embedding ID: 0_5
# Insert of existing embedding ID: 0_6
# Insert of existing embedding ID: 0_7
# Insert of existing embedding ID: 0_8
# Insert of existing embedding ID: 0_9
# Insert of existing embedding ID: 0_10
# Insert of existing embedding ID: 0_11
# Insert of existing embedding ID: 0_12
# Insert of existing embedding ID: 0_13
# Insert of existing embedding ID: 0_14
# Insert of existing embedding ID: 0_15
# Insert of existing embedding ID: 0_16
# Insert of existing embedding ID: 0_17
# Insert of existing embedding ID: 0_18
# Insert of existing embedding ID: 0_19
# Insert of existing embedding ID: 0_20
# Insert of existing embedding ID: 0_21
# Insert of existing embedding ID: 0_22
# Insert of existing embedding ID: 0_23
# Insert of existing embedding ID: 0_24
# Insert of existing embedding ID: 0_25
# Insert of existing embedding ID: 0_26
# Insert of existing embedding ID: 0_27
# Insert of existing embedding ID: 0_28
# Insert of existing embedding ID: 0_29
# Insert of existing embedding ID: 0_30
# Insert of existing embedding ID: 0_31
# Insert of existing embedding ID: 0_32
# Insert of existing embedding ID: 0_33
# Insert of existing embedding ID: 0_34
# Insert of existing embedding ID: 0_35
# Insert of existing embedding ID: 0_36
# Insert of existing embedding ID: 0_37
# Insert of existing embedding ID: 0_38
# Insert of existing embedding ID: 0_39
# Insert of existing embedding ID: 0_40
# Insert of existing embedding ID: 0_41
# Insert of existing embedding ID: 0_42
# Insert of existing embedding ID: 0_43
# Insert of existing embedding ID: 0_44
# Insert of existing embedding ID: 0_45
# Insert of existing embedding ID: 0_46
# Insert of existing embedding ID: 0_47
# Insert of existing embedding ID: 0_48
# Insert of existing embedding ID: 0_49
# Insert of existing embedding ID: 0_50
# True

# %%
query = "whats is Transformers?"

retrieved_docs = rag_agent.search_document(query)

# %%
context = "\n\n".join(retrieved_docs["documents"][0])

# %%
rag_agent.chat_assistant.get_chat_response(query, retrieved_docs=context)
# Out:
# 'According to the context, a "Transformers" is mentioned as the first transduction model that relies entirely on self-attention to compute representations of its input and output without using sequence-aligned RNNs or convolution.'

# %%
# !rm -rvf "./chromadb_data/"

# rag_agent.delete_collection()

# %%
documents = rag_agent.load_and_process_xlsx("../docs/FAQ_sample.xlsx")

# %%
documents
# Out:
# [{'source': 'xlsx',
#   'page': 0,
#   'chunk_idx': 0,
#   'text': "Question: How can I regroup elements on a slide after ungrouping?\nAnswer: Currently, once elements are ungrouped, they cannot be regrouped. This feature is on our roadmap, but we don't have a specific timeline yet.",
#   'question': 'How can I regroup elements on a slide after ungrouping?',
#   'answer': "Currently, once elements are ungrouped, they cannot be regrouped. This feature is on our roadmap, but we don't have a specific timeline yet."},
#  {'source': 'xlsx',
#   'page': 1,
#   'chunk_idx': 0,
#   'text': 'Question: How can I add my company logo to all slides?\nAnswer: You can add your company logo to the footer via the footer settings in the right sidebar. Please note that not all slide layouts support footers due to aesthetic considerations.',
#   'question': 'How can I add my company logo to all slides?',
#   'answer': 'You can add your company logo to the footer via the footer settings in the right sidebar. Please note that not all slide layouts support footers due to aesthetic considerations.'},
#  {'source': 'xlsx',
#   'page': 2,
#   'chunk_idx': 0,
#   'text': "Question: How can I upload and access stock images for use in my presentations?\nAnswer: While we don't currently support adding multiple images to a library for use across presentations, every image you upload is stored in the Media Gallery under 'Your Image.' You can access it when adding or replacing an image.",
#   'question': 'How can I upload and access stock images for use in my presentations?',
#   'answer': "While we don't currently support adding multiple images to a library for use across presentations, every image you upload is stored in the Media Gallery under 'Your Image.' You can access it when adding or replacing an image."},
#  {'source': 'xlsx',
#   'page': 3,
#   'chunk_idx': 0,
#   'text': "Question: How can I embed a video into my presentation slides?\nAnswer: You can embed YouTube videos by following these steps: Add a new slide, choose 'Video' under 'Essential Slides,' click 'Edit Embed Link' at the bottom of the slide, and insert your video link.",
#   'question': 'How can I embed a video into my presentation slides?',
#   'answer': "You can embed YouTube videos by following these steps: Add a new slide, choose 'Video' under 'Essential Slides,' click 'Edit Embed Link' at the bottom of the slide, and insert your video link."},
#  {'source': 'xlsx',
#   'page': 4,
#   'chunk_idx': 0,
#   'text': 'Question: How can I add speaker notes to every slide, like in PowerPoint?\nAnswer: We are currently updating the speaker notes feature, which has been temporarily disabled in presentation mode. It will be relaunched in a few weeks.',
#   'question': 'How can I add speaker notes to every slide, like in PowerPoint?',
#   'answer': 'We are currently updating the speaker notes feature, which has been temporarily disabled in presentation mode. It will be relaunched in a few weeks.'},
#  {'source': 'xlsx',
#   'page': 5,
#   'chunk_idx': 0,
#   'text': "Question: How can I increase the size of a table in my presentation?\nAnswer: To change the text size in a table: Select the column or row, choose the font size from the contextual menu. At this time, you can't change the text sizes of multiple elements simultaneously. This feature is on our roadmap.",
#   'question': 'How can I increase the size of a table in my presentation?',
#   'answer': "To change the text size in a table: Select the column or row, choose the font size from the contextual menu. At this time, you can't change the text sizes of multiple elements simultaneously. This feature is on our roadmap."},
#  {'source': 'xlsx',
#   'page': 6,
#   'chunk_idx': 0,
#   'text': 'Question: Is it possible to automatically add the original script provided for AI-generated slides to the speaker notes?\nAnswer: Unfortunately, this is not currently possible. However, you can generate speaker notes using AI in the Presentation Editor by selecting ‘Notes’ from the right panel.',
#   'question': 'Is it possible to automatically add the original script provided for AI-generated slides to the speaker notes?',
#   'answer': 'Unfortunately, this is not currently possible. However, you can generate speaker notes using AI in the Presentation Editor by selecting ‘Notes’ from the right panel.'},
#  {'source': 'xlsx',
#   'page': 7,
#   'chunk_idx': 0,
#   'text': 'Question: How can I save my presentation?\nAnswer: Presentations are autosaved. To manually save a presentation: Open the presentation in editor mode, click the Save icon in the top toolbar.',
#   'question': 'How can I save my presentation?',
#   'answer': 'Presentations are autosaved. To manually save a presentation: Open the presentation in editor mode, click the Save icon in the top toolbar.'},
#  {'source': 'xlsx',
#   'page': 8,
#   'chunk_idx': 0,
#   'text': "Question: Why don’t some slides show a footer even though I selected 'Add footer to all pages,' and how can I ensure a footer appears on every slide?\nAnswer: Footers are not displayed on certain layouts, such as intro and conclusion slides, to maintain design consistency. You can explore which layouts support footers by clicking the 'Remix' option at the bottom right of the slide.",
#   'question': "Why don’t some slides show a footer even though I selected 'Add footer to all pages,' and how can I ensure a footer appears on every slide?",
#   'answer': "Footers are not displayed on certain layouts, such as intro and conclusion slides, to maintain design consistency. You can explore which layouts support footers by clicking the 'Remix' option at the bottom right of the slide."},
#  {'source': 'xlsx',
#   'page': 9,
#   'chunk_idx': 0,
#   'text': "Question: How can I change the slide transition animation while keeping animations within slide sections?\nAnswer: To change slide transition animations: Select a slide, click 'Animation' in the right sidebar, choose your preferred animation type. Note: This option may not be available for certain slide types, like intro slides.",
#   'question': 'How can I change the slide transition animation while keeping animations within slide sections?',
#   'answer': "To change slide transition animations: Select a slide, click 'Animation' in the right sidebar, choose your preferred animation type. Note: This option may not be available for certain slide types, like intro slides."},
#  {'source': 'xlsx',
#   'page': 10,
#   'chunk_idx': 0,
#   'text': "Question: Where can I find images or graphics to replace the default ones in my presentation?\nAnswer: To replace an image: Select an image in the presentation, click 'Replace' in the contextual menu, upload an image from your system or choose one from our library. If the slide doesn’t have images, click on 'Layout' at the bottom left, choose a design that supports images, and then replace the image.",
#   'question': 'Where can I find images or graphics to replace the default ones in my presentation?',
#   'answer': "To replace an image: Select an image in the presentation, click 'Replace' in the contextual menu, upload an image from your system or choose one from our library. If the slide doesn’t have images, click on 'Layout' at the bottom left, choose a design that supports images, and then replace the image."},
#  {'source': 'xlsx',
#   'page': 11,
#   'chunk_idx': 0,
#   'text': "Question: Why can't I invite someone to collaborate on my design?\nAnswer: Collaboration features are available only to customers with multi-user licenses on Pro plans.",
#   'question': "Why can't I invite someone to collaborate on my design?",
#   'answer': 'Collaboration features are available only to customers with multi-user licenses on Pro plans.'},
#  {'source': 'xlsx',
#   'page': 12,
#   'chunk_idx': 0,
#   'text': "Question: Why can't I cut and paste slides between presentations?\nAnswer: The copy/paste functionality has been temporarily disabled due to some issues. We are working on a fix and will release it soon. In the meantime, you can export presentations and combine them offline.",
#   'question': "Why can't I cut and paste slides between presentations?",
#   'answer': 'The copy/paste functionality has been temporarily disabled due to some issues. We are working on a fix and will release it soon. In the meantime, you can export presentations and combine them offline.'},
#  {'source': 'xlsx',
#   'page': 13,
#   'chunk_idx': 0,
#   'text': 'Question: What file formats can I use to create a presentation?\nAnswer: On the Pro plan, you can upload PDF or Word documents up to 20 MB. On the free plan, the limit is 5 MB.',
#   'question': 'What file formats can I use to create a presentation?',
#   'answer': 'On the Pro plan, you can upload PDF or Word documents up to 20 MB. On the free plan, the limit is 5 MB.'},
#  {'source': 'xlsx',
#   'page': 14,
#   'chunk_idx': 0,
#   'text': "Question: Do you offer an API?\nAnswer: We do not currently offer API services, but it's on our roadmap. Please share your requirements with us at support@presentations.ai, and we’ll forward them to our engineering team.",
#   'question': 'Do you offer an API?',
#   'answer': "We do not currently offer API services, but it's on our roadmap. Please share your requirements with us at support@presentations.ai, and we’ll forward them to our engineering team."},
#  {'source': 'xlsx',
#   'page': 15,
#   'chunk_idx': 0,
#   'text': 'Question: Can I translate an existing presentation?\nAnswer: Translating an existing presentation is not currently possible, but this feature is on our product roadmap.',
#   'question': 'Can I translate an existing presentation?',
#   'answer': 'Translating an existing presentation is not currently possible, but this feature is on our product roadmap.'},
#  {'source': 'xlsx',
#   'page': 16,
#   'chunk_idx': 0,
#   'text': "Question: How can I change the background color or image of a slide?\nAnswer: To change the background image: Click the 'Remix' button at the bottom of the slide, navigate to 'Background Images,' select a style, and click 'Apply Style.'",
#   'question': 'How can I change the background color or image of a slide?',
#   'answer': "To change the background image: Click the 'Remix' button at the bottom of the slide, navigate to 'Background Images,' select a style, and click 'Apply Style.'"},
#  {'source': 'xlsx',
#   'page': 17,
#   'chunk_idx': 0,
#   'text': "Question: How do I publish my presentation to share with others?\nAnswer: To publish a presentation: Open the presentation, click 'Share and Export,' select 'Publish' and then copy the link.",
#   'question': 'How do I publish my presentation to share with others?',
#   'answer': "To publish a presentation: Open the presentation, click 'Share and Export,' select 'Publish' and then copy the link."},
#  {'source': 'xlsx',
#   'page': 18,
#   'chunk_idx': 0,
#   'text': "Question: How do I delete a presentation?\nAnswer: To delete a presentation: Go to the dashboard, click the three-dot menu next to the presentation, select 'Delete' and confirm. For multiple presentations, select the presentations using the checkboxes, click 'Delete,' and confirm. Note: Deleted presentations cannot be recovered.",
#   'question': 'How do I delete a presentation?',
#   'answer': "To delete a presentation: Go to the dashboard, click the three-dot menu next to the presentation, select 'Delete' and confirm. For multiple presentations, select the presentations using the checkboxes, click 'Delete,' and confirm. Note: Deleted presentations cannot be recovered."},
#  {'source': 'xlsx',
#   'page': 19,
#   'chunk_idx': 0,
#   'text': 'Question: Can I combine multiple presentations?\nAnswer: Currently, you cannot combine multiple presentations. This feature is on our roadmap.',
#   'question': 'Can I combine multiple presentations?',
#   'answer': 'Currently, you cannot combine multiple presentations. This feature is on our roadmap.'},
#  {'source': 'xlsx',
#   'page': 20,
#   'chunk_idx': 0,
#   'text': 'Question: How do I change the font size?\nAnswer: Select the text, then use the font size options in the contextual menu or settings panel.',
#   'question': 'How do I change the font size?',
#   'answer': 'Select the text, then use the font size options in the contextual menu or settings panel.'},
#  {'source': 'xlsx',
#   'page': 21,
#   'chunk_idx': 0,
#   'text': 'Question: How do I change the image transparency in a slide?\nAnswer: To change image transparency: Select the image, click the settings option in the contextual menu, adjust the transparency settings in the right panel.',
#   'question': 'How do I change the image transparency in a slide?',
#   'answer': 'To change image transparency: Select the image, click the settings option in the contextual menu, adjust the transparency settings in the right panel.'},
#  {'source': 'xlsx',
#   'page': 22,
#   'chunk_idx': 0,
#   'text': "Question: How do I replace an image in my presentation?\nAnswer: To replace an existing image: Select the image, click 'Replace' in the contextual menu, upload a new image or select one from the library. If the slide doesn’t have images, select 'Layout' at the bottom left, choose a design that supports images, and replace the image.",
#   'question': 'How do I replace an image in my presentation?',
#   'answer': "To replace an existing image: Select the image, click 'Replace' in the contextual menu, upload a new image or select one from the library. If the slide doesn’t have images, select 'Layout' at the bottom left, choose a design that supports images, and replace the image."},
#  {'source': 'xlsx',
#   'page': 23,
#   'chunk_idx': 0,
#   'text': 'Question: Can I set a default presentation style?\nAnswer: Yes, navigate to Dashboard > Settings > Presentation Style to choose a default style. All presentations created from your account will use this style.',
#   'question': 'Can I set a default presentation style?',
#   'answer': 'Yes, navigate to Dashboard > Settings > Presentation Style to choose a default style. All presentations created from your account will use this style.'},
#  {'source': 'xlsx',
#   'page': 24,
#   'chunk_idx': 0,
#   'text': "Question: How do I add a blank slide?\nAnswer: Click the '+' icon next to any slide, choose the slide type, and add your content.",
#   'question': 'How do I add a blank slide?',
#   'answer': "Click the '+' icon next to any slide, choose the slide type, and add your content."},
#  {'source': 'xlsx',
#   'page': 25,
#   'chunk_idx': 0,
#   'text': 'Question: Can I upload an existing PowerPoint presentation?\nAnswer: Currently, you cannot upload a PowerPoint presentation. However, you can generate presentations from Word or PDF documents.',
#   'question': 'Can I upload an existing PowerPoint presentation?',
#   'answer': 'Currently, you cannot upload a PowerPoint presentation. However, you can generate presentations from Word or PDF documents.'},
#  {'source': 'xlsx',
#   'page': 26,
#   'chunk_idx': 0,
#   'text': "Question: How can I add a new text-only slide?\nAnswer: Click the plus icon on the right of the slide, hover over 'Title Slide' in the Essential Slides tab, and select ‘Remix.’ Choose the 'Drop in Letter' template from the Variations.",
#   'question': 'How can I add a new text-only slide?',
#   'answer': "Click the plus icon on the right of the slide, hover over 'Title Slide' in the Essential Slides tab, and select ‘Remix.’ Choose the 'Drop in Letter' template from the Variations."},
#  {'source': 'xlsx',
#   'page': 27,
#   'chunk_idx': 0,
#   'text': 'Question: Is there a speaker view available for presentations?\nAnswer: A separate speaker view is not available at this time.',
#   'question': 'Is there a speaker view available for presentations?',
#   'answer': 'A separate speaker view is not available at this time.'},
#  {'source': 'xlsx',
#   'page': 28,
#   'chunk_idx': 0,
#   'text': 'Question: Can I integrate Presentations.ai with my OpenAI account?\nAnswer: Integration with OpenAI accounts is not currently supported.',
#   'question': 'Can I integrate Presentations.ai with my OpenAI account?',
#   'answer': 'Integration with OpenAI accounts is not currently supported.'},
#  {'source': 'xlsx',
#   'page': 29,
#   'chunk_idx': 0,
#   'text': 'Question: Can I export my presentation as a video?\nAnswer: We do not currently offer the option to export presentations as videos.',
#   'question': 'Can I export my presentation as a video?',
#   'answer': 'We do not currently offer the option to export presentations as videos.'},
#  {'source': 'xlsx',
#   'page': 30,
#   'chunk_idx': 0,
#   'text': "Question: Can I create charts and diagrams in my presentations?\nAnswer: Yes, we offer a variety of charts and diagrams. You can use the 'Add Slide' feature to explore and select the appropriate visualization.",
#   'question': 'Can I create charts and diagrams in my presentations?',
#   'answer': "Yes, we offer a variety of charts and diagrams. You can use the 'Add Slide' feature to explore and select the appropriate visualization."},
#  {'source': 'xlsx',
#   'page': 31,
#   'chunk_idx': 0,
#   'text': 'Question: Is there a way to see my credit usage history?\nAnswer: Navigate to Settings → Plan and Billing → View History to see your credit usage. Please allow a few seconds for the history to load.',
#   'question': 'Is there a way to see my credit usage history?',
#   'answer': 'Navigate to Settings → Plan and Billing → View History to see your credit usage. Please allow a few seconds for the history to load.'},
#  {'source': 'xlsx',
#   'page': 32,
#   'chunk_idx': 0,
#   'text': "Question: How can I delete individual elements from a slide without deleting the entire slide?\nAnswer: To delete individual elements: Click on 'More Options' (three-dot menu) at the top right of the slide, select 'Ungroup Slide,' click on each element you wish to remove and press delete. Note: Once ungrouped, elements cannot be regrouped. This functionality is planned for a future update.",
#   'question': 'How can I delete individual elements from a slide without deleting the entire slide?',
#   'answer': "To delete individual elements: Click on 'More Options' (three-dot menu) at the top right of the slide, select 'Ungroup Slide,' click on each element you wish to remove and press delete. Note: Once ungrouped, elements cannot be regrouped. This functionality is planned for a future update."},
#  {'source': 'xlsx',
#   'page': 33,
#   'chunk_idx': 0,
#   'text': "Question: How can I embed a Vimeo video into my presentation?\nAnswer: Vimeo embedding is not supported yet, but it's on our roadmap. Currently, you can embed videos from YouTube, Twitter, or Figma.",
#   'question': 'How can I embed a Vimeo video into my presentation?',
#   'answer': "Vimeo embedding is not supported yet, but it's on our roadmap. Currently, you can embed videos from YouTube, Twitter, or Figma."},
#  {'source': 'xlsx',
#   'page': 34,
#   'chunk_idx': 0,
#   'text': 'Question: How can I change the font type in my presentation?\nAnswer: Use the right-side toolbar to change the font type by navigating to Themes > Font.',
#   'question': 'How can I change the font type in my presentation?',
#   'answer': 'Use the right-side toolbar to change the font type by navigating to Themes > Font.'},
#  {'source': 'xlsx',
#   'page': 35,
#   'chunk_idx': 0,
#   'text': 'Question: Why are my payments being denied when subscribing to the Pro plan?\nAnswer: We’ve checked our payment gateway, Stripe, and there were no issues on our end when you tried making the payment. The problem could be with your payment method. Please double-check your payment information, ensure your card is authorized for online or international transactions, or try a different payment method. For customers in India, we offer bank transfer options. If the issue persists, contact your bank for assistance, or reach out to us at support@presentations.ai.',
#   'question': 'Why are my payments being denied when subscribing to the Pro plan?',
#   'answer': 'We’ve checked our payment gateway, Stripe, and there were no issues on our end when you tried making the payment. The problem could be with your payment method. Please double-check your payment information, ensure your card is authorized for online or international transactions, or try a different payment method. For customers in India, we offer bank transfer options. If the issue persists, contact your bank for assistance, or reach out to us at support@presentations.ai.'},
#  {'source': 'xlsx',
#   'page': 36,
#   'chunk_idx': 0,
#   'text': 'Question: Can I subscribe to a monthly plan instead of paying the annual fee upfront?\nAnswer: We do not offer a monthly plan as part of our standard offering. However, in special cases, such as NGOs, non-profits or academicians, we can consider it. Please contact us at support@presentations.ai if you are interested in a monthly plan.',
#   'question': 'Can I subscribe to a monthly plan instead of paying the annual fee upfront?',
#   'answer': 'We do not offer a monthly plan as part of our standard offering. However, in special cases, such as NGOs, non-profits or academicians, we can consider it. Please contact us at support@presentations.ai if you are interested in a monthly plan.'},
#  {'source': 'xlsx',
#   'page': 37,
#   'chunk_idx': 0,
#   'text': "Question: What is the difference between 'Pro' and 'Team' subscriptions?\nAnswer: We offer two main plans: Free Plan: Create up to 40 slides, without export functionality. Pro Plan: Available as a single-user or multi-user license. Multi-user plans can include 5 to 50 licenses.",
#   'question': "What is the difference between 'Pro' and 'Team' subscriptions?",
#   'answer': 'We offer two main plans: Free Plan: Create up to 40 slides, without export functionality. Pro Plan: Available as a single-user or multi-user license. Multi-user plans can include 5 to 50 licenses.'},
#  {'source': 'xlsx',
#   'page': 38,
#   'chunk_idx': 0,
#   'text': 'Question: Can I request a refund for the annual Pro plan as I intended to subscribe to the monthly plan instead?\nAnswer: While our policy generally does not allow refunds on purchased plans, we prioritize your satisfaction. We can offer you additional credits to your account. Currently, you have 5,000 credits. We would be happy to add an additional 2,000 credits to your account.',
#   'question': 'Can I request a refund for the annual Pro plan as I intended to subscribe to the monthly plan instead?',
#   'answer': 'While our policy generally does not allow refunds on purchased plans, we prioritize your satisfaction. We can offer you additional credits to your account. Currently, you have 5,000 credits. We would be happy to add an additional 2,000 credits to your account.'},
#  {'source': 'xlsx',
#   'page': 39,
#   'chunk_idx': 0,
#   'text': 'Question: Why was I charged $30 when I only requested a testing period, and can I get a refund?\nAnswer: Please note that if you subscribed to a monthly plan and forgot to cancel before the next billing cycle, you might have been charged. You can cancel the subscription before the next payment cycle via Settings → Plans and Billing → ‘Cancel Renewal.’',
#   'question': 'Why was I charged $30 when I only requested a testing period, and can I get a refund?',
#   'answer': 'Please note that if you subscribed to a monthly plan and forgot to cancel before the next billing cycle, you might have been charged. You can cancel the subscription before the next payment cycle via Settings → Plans and Billing → ‘Cancel Renewal.’'},
#  {'source': 'xlsx',
#   'page': 40,
#   'chunk_idx': 0,
#   'text': "Question: Why hasn't our Team license been activated yet after making a bank transfer?\nAnswer: SEPA payments can take 1-2 business days to process. Additionally, delays may occur due to bank processing times, batch processing, or verification checks. Your Pro license will be activated within the next 24 hours.",
#   'question': "Why hasn't our Team license been activated yet after making a bank transfer?",
#   'answer': 'SEPA payments can take 1-2 business days to process. Additionally, delays may occur due to bank processing times, batch processing, or verification checks. Your Pro license will be activated within the next 24 hours.'},
#  {'source': 'xlsx',
#   'page': 41,
#   'chunk_idx': 0,
#   'text': "Question: How can I upgrade from the Pro plan to the Team plan?\nAnswer: To upgrade: Navigate to 'Settings' from the left panel, select 'Plans and Billing,' choose the number of licenses, and complete the payment process.",
#   'question': 'How can I upgrade from the Pro plan to the Team plan?',
#   'answer': "To upgrade: Navigate to 'Settings' from the left panel, select 'Plans and Billing,' choose the number of licenses, and complete the payment process."},
#  {'source': 'xlsx',
#   'page': 42,
#   'chunk_idx': 0,
#   'text': 'Question: How can I cancel my free trial before being charged, as I cannot find the option in account settings?\nAnswer: You won’t be charged because we don’t collect credit card or bank information for the free plan.',
#   'question': 'How can I cancel my free trial before being charged, as I cannot find the option in account settings?',
#   'answer': 'You won’t be charged because we don’t collect credit card or bank information for the free plan.'},
#  {'source': 'xlsx',
#   'page': 43,
#   'chunk_idx': 0,
#   'text': 'Question: How many credits do I get with the Pro plan and how are they used?\nAnswer: The Pro plan includes 5,000 credits. Credits are used as follows: Creating a slide: 5 credits per slide. Exporting to PPT: 5 credits per slide. With 5,000 credits, you can create and export up to 500 slides. Additional credits can be purchased as needed.',
#   'question': 'How many credits do I get with the Pro plan and how are they used?',
#   'answer': 'The Pro plan includes 5,000 credits. Credits are used as follows: Creating a slide: 5 credits per slide. Exporting to PPT: 5 credits per slide. With 5,000 credits, you can create and export up to 500 slides. Additional credits can be purchased as needed.'},
#  {'source': 'xlsx',
#   'page': 44,
#   'chunk_idx': 0,
#   'text': 'Question: Do you have an Enterprise plan?\nAnswer: Yes, we offer: 50-user plan: $4,000/year with 100,000 credits. 50-user plan with unlimited credits: $10,000/year. Custom template setup: $1,200 (included with the 50-user unlimited credits plan). Please contact us at support@presentations.ai to discuss your requirements and find a tailored solution.',
#   'question': 'Do you have an Enterprise plan?',
#   'answer': 'Yes, we offer: 50-user plan: $4,000/year with 100,000 credits. 50-user plan with unlimited credits: $10,000/year. Custom template setup: $1,200 (included with the 50-user unlimited credits plan). Please contact us at support@presentations.ai to discuss your requirements and find a tailored solution.'},
#  {'source': 'xlsx',
#   'page': 45,
#   'chunk_idx': 0,
#   'text': 'Question: How can I cancel the direct debit from my bank account?\nAnswer: To cancel a direct debit, you need to contact your bank or payment provider directly.',
#   'question': 'How can I cancel the direct debit from my bank account?',
#   'answer': 'To cancel a direct debit, you need to contact your bank or payment provider directly.'},
#  {'source': 'xlsx',
#   'page': 46,
#   'chunk_idx': 0,
#   'text': 'Question: Can I get a free month on your plan and pay for it starting next month, with the option to cancel anytime?\nAnswer: Unfortunately, we do not offer a free month plan.',
#   'question': 'Can I get a free month on your plan and pay for it starting next month, with the option to cancel anytime?',
#   'answer': 'Unfortunately, we do not offer a free month plan.'},
#  {'source': 'xlsx',
#   'page': 47,
#   'chunk_idx': 0,
#   'text': 'Question: How long does the trial for Presentations.ai last?\nAnswer: The trial is credit-based, not time-based, so you can use it until your credits run out.',
#   'question': 'How long does the trial for Presentations.ai last?',
#   'answer': 'The trial is credit-based, not time-based, so you can use it until your credits run out.'},
#  {'source': 'xlsx',
#   'page': 48,
#   'chunk_idx': 0,
#   'text': 'Question: Will using the same prompt generate an identical presentation?\nAnswer: Using the same prompt will produce similar presentations, but exact replicas are challenging due to the AI’s inherent variability. To maintain consistency, specify details in your prompt or adjust the outline.',
#   'question': 'Will using the same prompt generate an identical presentation?',
#   'answer': 'Using the same prompt will produce similar presentations, but exact replicas are challenging due to the AI’s inherent variability. To maintain consistency, specify details in your prompt or adjust the outline.'},
#  {'source': 'xlsx',
#   'page': 49,
#   'chunk_idx': 0,
#   'text': 'Question: How can I use AI to generate a new slide and reword content after my presentation has already been created?\nAnswer: Currently, AI cannot generate new slides after a presentation is created. You can modify the outline before creation, and AI-powered slide creation for existing presentations is on our roadmap.',
#   'question': 'How can I use AI to generate a new slide and reword content after my presentation has already been created?',
#   'answer': 'Currently, AI cannot generate new slides after a presentation is created. You can modify the outline before creation, and AI-powered slide creation for existing presentations is on our roadmap.'},
#  {'source': 'xlsx',
#   'page': 50,
#   'chunk_idx': 0,
#   'text': "Question: Is it possible to upload a Word file without any alterations to the text in the presentation?\nAnswer: The 'Preserved' option is designed to keep the text exactly as it is. If you experience any issues, please contact our support team for further investigation.",
#   'question': 'Is it possible to upload a Word file without any alterations to the text in the presentation?',
#   'answer': "The 'Preserved' option is designed to keep the text exactly as it is. If you experience any issues, please contact our support team for further investigation."},
#  {'source': 'xlsx',
#   'page': 51,
#   'chunk_idx': 0,
#   'text': 'Question: Is there a limit to the number of slides I can create?\nAnswer: Presentations can have between 1 and 30 slides.',
#   'question': 'Is there a limit to the number of slides I can create?',
#   'answer': 'Presentations can have between 1 and 30 slides.'},
#  {'source': 'xlsx',
#   'page': 52,
#   'chunk_idx': 0,
#   'text': 'Question: Can I create presentations in languages other than English?\nAnswer: Yes, our platform supports multiple languages.',
#   'question': 'Can I create presentations in languages other than English?',
#   'answer': 'Yes, our platform supports multiple languages.'},
#  {'source': 'xlsx',
#   'page': 53,
#   'chunk_idx': 0,
#   'text': "Question: How can I create a presentation with my existing content and have Presentations.ai build the template for me?\nAnswer: You can upload your content as a document using the 'Import docs' feature.",
#   'question': 'How can I create a presentation with my existing content and have Presentations.ai build the template for me?',
#   'answer': "You can upload your content as a document using the 'Import docs' feature."},
#  {'source': 'xlsx',
#   'page': 54,
#   'chunk_idx': 0,
#   'text': 'Question: Can your AI create presentations from a spreadsheet/Excel/Google Sheets?\nAnswer: Not at this time, but this feature is being considered for future development.',
#   'question': 'Can your AI create presentations from a spreadsheet/Excel/Google Sheets?',
#   'answer': 'Not at this time, but this feature is being considered for future development.'},
#  {'source': 'xlsx',
#   'page': 55,
#   'chunk_idx': 0,
#   'text': 'Question: How can I choose the number of slides while preparing a presentation?\nAnswer: Pro users can select the number of slides (1-30) during prompt creation. Free users can select between 1-15 slides.',
#   'question': 'How can I choose the number of slides while preparing a presentation?',
#   'answer': 'Pro users can select the number of slides (1-30) during prompt creation. Free users can select between 1-15 slides.'},
#  {'source': 'xlsx',
#   'page': 56,
#   'chunk_idx': 0,
#   'text': "Question: How can I find my previous prompt on your website to improve and reuse it for a new presentation?\nAnswer: Currently, prompts cannot be reused. You'll need to create a new prompt for each presentation.",
#   'question': 'How can I find my previous prompt on your website to improve and reuse it for a new presentation?',
#   'answer': "Currently, prompts cannot be reused. You'll need to create a new prompt for each presentation."},
#  {'source': 'xlsx',
#   'page': 57,
#   'chunk_idx': 0,
#   'text': 'Question: Why was my presentation created without properly processing the uploaded file?\nAnswer: Please share the prompt or document used to create the presentation by emailing us at support@presentations.ai for investigation.',
#   'question': 'Why was my presentation created without properly processing the uploaded file?',
#   'answer': 'Please share the prompt or document used to create the presentation by emailing us at support@presentations.ai for investigation.'},
#  {'source': 'xlsx',
#   'page': 58,
#   'chunk_idx': 0,
#   'text': 'Question: Why does the product fail to read my files and create an outline?\nAnswer: Please share the prompt or document used to create the presentation by emailing us at support@presentations.ai for further investigation.',
#   'question': 'Why does the product fail to read my files and create an outline?',
#   'answer': 'Please share the prompt or document used to create the presentation by emailing us at support@presentations.ai for further investigation.'},
#  {'source': 'xlsx',
#   'page': 59,
#   'chunk_idx': 0,
#   'text': 'Question: Why does the app keep crashing?\nAnswer: We apologize for the inconvenience. Please provide details, including the document title, to support@presentations.ai so our engineering team can investigate and resolve the issue.',
#   'question': 'Why does the app keep crashing?',
#   'answer': 'We apologize for the inconvenience. Please provide details, including the document title, to support@presentations.ai so our engineering team can investigate and resolve the issue.'},
#  {'source': 'xlsx',
#   'page': 60,
#   'chunk_idx': 0,
#   'text': 'Question: Why did some slides lose information, and can you assist in recovering it?\nAnswer: We sincerely apologize for the inconvenience. Please share the title of the presentation experiencing this issue with us at support@presentations.ai.',
#   'question': 'Why did some slides lose information, and can you assist in recovering it?',
#   'answer': 'We sincerely apologize for the inconvenience. Please share the title of the presentation experiencing this issue with us at support@presentations.ai.'},
#  {'source': 'xlsx',
#   'page': 61,
#   'chunk_idx': 0,
#   'text': 'Question: Why am I being charged credits repeatedly for downloading a PPT, and still can’t download it?\nAnswer: Please share the title of the presentation with us at support@presentations.ai so we can address the issue.',
#   'question': 'Why am I being charged credits repeatedly for downloading a PPT, and still can’t download it?',
#   'answer': 'Please share the title of the presentation with us at support@presentations.ai so we can address the issue.'},
#  {'source': 'xlsx',
#   'page': 62,
#   'chunk_idx': 0,
#   'text': 'Question: Why is my shared presentation link not working?\nAnswer: Apologies. Please try again, and if the issue persists, share the presentation link with us for further investigation.',
#   'question': 'Why is my shared presentation link not working?',
#   'answer': 'Apologies. Please try again, and if the issue persists, share the presentation link with us for further investigation.'},
#  {'source': 'xlsx',
#   'page': 63,
#   'chunk_idx': 0,
#   'text': 'Question: Why did all the data disappear after downloading the presentation as a PPT, and can you help recover it?\nAnswer: Unfortunately, we are unable to recover lost data. Please share the title of the presentation with us at support@presentations.ai for investigation.',
#   'question': 'Why did all the data disappear after downloading the presentation as a PPT, and can you help recover it?',
#   'answer': 'Unfortunately, we are unable to recover lost data. Please share the title of the presentation with us at support@presentations.ai for investigation.'},
#  {'source': 'xlsx',
#   'page': 64,
#   'chunk_idx': 0,
#   'text': 'Question: Why is the payment section of the page blank and not loading?\nAnswer: Please contact support@presentations.ai for assistance in resolving the issue.',
#   'question': 'Why is the payment section of the page blank and not loading?',
#   'answer': 'Please contact support@presentations.ai for assistance in resolving the issue.'},
#  {'source': 'xlsx',
#   'page': 65,
#   'chunk_idx': 0,
#   'text': 'Question: Can I use presentations created on Presentation.AI for commercial purposes, like selling them in HTML5 or SCORM format for eLearning platforms?\nAnswer: Yes, you can use the content you create with Presentation.AI for commercial purposes, including selling derivative works. However, ensure the images or graphics used are properly licensed.',
#   'question': 'Can I use presentations created on Presentation.AI for commercial purposes, like selling them in HTML5 or SCORM format for eLearning platforms?',
#   'answer': 'Yes, you can use the content you create with Presentation.AI for commercial purposes, including selling derivative works. However, ensure the images or graphics used are properly licensed.'},
#  {'source': 'xlsx',
#   'page': 66,
#   'chunk_idx': 0,
#   'text': 'Question: Do users have the right to use generated images for commercial purposes, such as on monetized YouTube channels?\nAnswer: Yes, all images generated within the platform can be used for commercial purposes.',
#   'question': 'Do users have the right to use generated images for commercial purposes, such as on monetized YouTube channels?',
#   'answer': 'Yes, all images generated within the platform can be used for commercial purposes.'},
#  {'source': 'xlsx',
#   'page': 67,
#   'chunk_idx': 0,
#   'text': 'Question: How can I transfer my subscription to a different email address?\nAnswer: Please provide the email address to which you want the subscription transferred, and ensure the recipient has signed up for the product using that email.',
#   'question': 'How can I transfer my subscription to a different email address?',
#   'answer': 'Please provide the email address to which you want the subscription transferred, and ensure the recipient has signed up for the product using that email.'},
#  {'source': 'xlsx',
#   'page': 68,
#   'chunk_idx': 0,
#   'text': "Question: Why can't I download after upgrading to the Pro plan, even though I have a receipt and invoice?\nAnswer: Ensure you are on the workspace linked to the Pro plan. If you have multiple workspaces, switch to the correct one from the dashboard.",
#   'question': "Why can't I download after upgrading to the Pro plan, even though I have a receipt and invoice?",
#   'answer': 'Ensure you are on the workspace linked to the Pro plan. If you have multiple workspaces, switch to the correct one from the dashboard.'},
#  {'source': 'xlsx',
#   'page': 69,
#   'chunk_idx': 0,
#   'text': 'Question: Why are transitions missing or different in the downloaded version of my presentation?\nAnswer: PowerPoint does not support all transitions, videos, and animations available on the website. As an alternative, you can publish the presentation and share the link with others.',
#   'question': 'Why are transitions missing or different in the downloaded version of my presentation?',
#   'answer': 'PowerPoint does not support all transitions, videos, and animations available on the website. As an alternative, you can publish the presentation and share the link with others.'},
#  {'source': 'xlsx',
#   'page': 70,
#   'chunk_idx': 0,
#   'text': 'Question: Can I export slides to Microsoft PowerPoint format with the Pro plan?\nAnswer: Yes, you can export presentations to PPT using credits if you are on the Pro plan.',
#   'question': 'Can I export slides to Microsoft PowerPoint format with the Pro plan?',
#   'answer': 'Yes, you can export presentations to PPT using credits if you are on the Pro plan.'},
#  {'source': 'xlsx',
#   'page': 71,
#   'chunk_idx': 0,
#   'text': 'Question: Can I download chart slides in an editable format for future use in PowerPoint?\nAnswer: Currently, charts are exported as images to ensure visual consistency. You may need to add additional slides after export to include editable data/charts manually.',
#   'question': 'Can I download chart slides in an editable format for future use in PowerPoint?',
#   'answer': 'Currently, charts are exported as images to ensure visual consistency. You may need to add additional slides after export to include editable data/charts manually.'},
#  {'source': 'xlsx',
#   'page': 72,
#   'chunk_idx': 0,
#   'text': 'Question: How can I download my presentation as a PPT file? [Free User]\nAnswer: PPT export is a paid feature. You can export presentations to PPT using credits if you are on the Pro plan.',
#   'question': 'How can I download my presentation as a PPT file? [Free User]',
#   'answer': 'PPT export is a paid feature. You can export presentations to PPT using credits if you are on the Pro plan.'},
#  {'source': 'xlsx',
#   'page': 73,
#   'chunk_idx': 0,
#   'text': "Question: How can I reduce the slide transition animation time?\nAnswer: You can’t customize animation time currently. To present without animation, select 'Without Animation' from the drop-down next to the play button.",
#   'question': 'How can I reduce the slide transition animation time?',
#   'answer': "You can’t customize animation time currently. To present without animation, select 'Without Animation' from the drop-down next to the play button."},
#  {'source': 'xlsx',
#   'page': 74,
#   'chunk_idx': 0,
#   'text': "Question: How can I remove all animations from my presentation deck?\nAnswer: To remove animations: Select 'Without Animation' from the drop-down next to the play button when presenting from the product. If publishing the presentation, deselect the animation option in 'Advanced Settings and Preview.'",
#   'question': 'How can I remove all animations from my presentation deck?',
#   'answer': "To remove animations: Select 'Without Animation' from the drop-down next to the play button when presenting from the product. If publishing the presentation, deselect the animation option in 'Advanced Settings and Preview.'"},
#  {'source': 'xlsx',
#   'page': 75,
#   'chunk_idx': 0,
#   'text': "Question: Why can't I download the PPT even though I already paid for it?\nAnswer: The downloadable link for your PPT export is typically sent to your registered email within minutes. You can also download it from the 'Custom Orders' tab below the 'Dashboard' tab.",
#   'question': "Why can't I download the PPT even though I already paid for it?",
#   'answer': "The downloadable link for your PPT export is typically sent to your registered email within minutes. You can also download it from the 'Custom Orders' tab below the 'Dashboard' tab."},
#  {'source': 'xlsx',
#   'page': 76,
#   'chunk_idx': 0,
#   'text': 'Question: How can I remove the Presentations.ai logo from my presentation?\nAnswer: With a Pro plan, you can remove Presentations.ai’s branding.',
#   'question': 'How can I remove the Presentations.ai logo from my presentation?',
#   'answer': 'With a Pro plan, you can remove Presentations.ai’s branding.'},
#  {'source': 'xlsx',
#   'page': 77,
#   'chunk_idx': 0,
#   'text': "Question: Can I upload my company's custom presentation format?\nAnswer: While you cannot currently upload a custom template, you can customize: Brand Colors: Incorporated into presentations when you update your company's website domain under 'Settings' → 'Org Information.' Logos, Icons, and Banners: Add these in 'Settings' → 'Brand' to be used in every presentation. Themes and Colors: Change these by navigating to 'Themes' in the right panel.",
#   'question': "Can I upload my company's custom presentation format?",
#   'answer': "While you cannot currently upload a custom template, you can customize: Brand Colors: Incorporated into presentations when you update your company's website domain under 'Settings' → 'Org Information.' Logos, Icons, and Banners: Add these in 'Settings' → 'Brand' to be used in every presentation. Themes and Colors: Change these by navigating to 'Themes' in the right panel."},
#  {'source': 'xlsx',
#   'page': 78,
#   'chunk_idx': 0,
#   'text': 'Question: How can I use my uploaded logo in the presentation?\nAnswer: Add your company logo to the footer via footer settings in the right sidebar. Note that not all slide layouts support footers.',
#   'question': 'How can I use my uploaded logo in the presentation?',
#   'answer': 'Add your company logo to the footer via footer settings in the right sidebar. Note that not all slide layouts support footers.'},
#  {'source': 'xlsx',
#   'page': 79,
#   'chunk_idx': 0,
#   'text': "Question: Why can't I change the font and colors in my brand kit settings?\nAnswer: Fonts and colors are set at the presentation level, not as a global setting. You can customize: Brand Colors: Incorporated into presentations when you update your company's website domain under 'Settings' → 'Org Information.' Logos, Icons, and Banners: Add these in 'Settings' → 'Brand' to be used in every presentation. Themes, Fonts, and Colors: Change these by navigating to 'Themes' in the right panel.",
#   'question': "Why can't I change the font and colors in my brand kit settings?",
#   'answer': "Fonts and colors are set at the presentation level, not as a global setting. You can customize: Brand Colors: Incorporated into presentations when you update your company's website domain under 'Settings' → 'Org Information.' Logos, Icons, and Banners: Add these in 'Settings' → 'Brand' to be used in every presentation. Themes, Fonts, and Colors: Change these by navigating to 'Themes' in the right panel."},
#  {'source': 'xlsx',
#   'page': 80,
#   'chunk_idx': 0,
#   'text': 'Question: Can you arrange a tool demo for our organization?\nAnswer: When you sign up, you receive 200 free credits to create presentations and explore our features. For further assistance or a Gmeet/Zoom call, please contact us at support@presentations.ai.',
#   'question': 'Can you arrange a tool demo for our organization?',
#   'answer': 'When you sign up, you receive 200 free credits to create presentations and explore our features. For further assistance or a Gmeet/Zoom call, please contact us at support@presentations.ai.'},
#  {'source': 'xlsx',
#   'page': 81,
#   'chunk_idx': 0,
#   'text': 'Question: Why did my credits decrease immediately after purchase without creating a presentation?\nAnswer: Credits may have been deducted due to a previous presentation attempt that exceeded the available credits. We’ve added 100 credits to your account as a courtesy.',
#   'question': 'Why did my credits decrease immediately after purchase without creating a presentation?',
#   'answer': 'Credits may have been deducted due to a previous presentation attempt that exceeded the available credits. We’ve added 100 credits to your account as a courtesy.'},
#  {'source': 'xlsx',
#   'page': 82,
#   'chunk_idx': 0,
#   'text': 'Question: Can I get more credits to test additional features before deciding to purchase?\nAnswer: Please share the email address associated with your account at support@presentations.ai, and we’ll add 500 more credits.',
#   'question': 'Can I get more credits to test additional features before deciding to purchase?',
#   'answer': 'Please share the email address associated with your account at support@presentations.ai, and we’ll add 500 more credits.'},
#  {'source': 'xlsx',
#   'page': 83,
#   'chunk_idx': 0,
#   'text': 'Question: Why do we have to pay for downloads? [Pro Plan]\nAnswer: We charge 5 credits per slide for PPT exports because it involves converting content into an editable format, which requires additional processing and resources. PDF/Image exports are free.',
#   'question': 'Why do we have to pay for downloads? [Pro Plan]',
#   'answer': 'We charge 5 credits per slide for PPT exports because it involves converting content into an editable format, which requires additional processing and resources. PDF/Image exports are free.'},
#  {'source': 'xlsx',
#   'page': 84,
#   'chunk_idx': 0,
#   'text': 'Question: What happens if I run out of credits?\nAnswer: You can purchase more credits from within the product as needed.',
#   'question': 'What happens if I run out of credits?',
#   'answer': 'You can purchase more credits from within the product as needed.'},
#  {'source': 'xlsx',
#   'page': 85,
#   'chunk_idx': 0,
#   'text': 'Question: How do credits work in the Pro plan? Do I get credits per month or per year, and are extra credits required for editing and exporting slides?\nAnswer: Credits are provided on a yearly basis. Editing slides doesn’t consume extra credits. Credits are used for creating slides, exporting slides, or using certain AI features like image generation.',
#   'question': 'How do credits work in the Pro plan? Do I get credits per month or per year, and are extra credits required for editing and exporting slides?',
#   'answer': 'Credits are provided on a yearly basis. Editing slides doesn’t consume extra credits. Credits are used for creating slides, exporting slides, or using certain AI features like image generation.'},
#  {'source': 'xlsx',
#   'page': 86,
#   'chunk_idx': 0,
#   'text': "Question: Can you reissue the invoice in the name of our company instead of the original name?\nAnswer: Please send us the details at support@presentations.ai, and we'll update the billing information and reissue the invoice within 1-2 business days.",
#   'question': 'Can you reissue the invoice in the name of our company instead of the original name?',
#   'answer': "Please send us the details at support@presentations.ai, and we'll update the billing information and reissue the invoice within 1-2 business days."},
#  {'source': 'xlsx',
#   'page': 87,
#   'chunk_idx': 0,
#   'text': 'Question: How can we claim GST tax credit?\nAnswer: Our company is registered in Singapore, and we can provide relevant invoices for your records.',
#   'question': 'How can we claim GST tax credit?',
#   'answer': 'Our company is registered in Singapore, and we can provide relevant invoices for your records.'},
#  {'source': 'xlsx',
#   'page': 88,
#   'chunk_idx': 0,
#   'text': 'Question: How secure is my data on Presentations.ai?\nAnswer: We adhere to the terms of OpenAI/Anthropic. Your data remains secure and is not used to train our models. For more information, please review our terms and privacy policy.',
#   'question': 'How secure is my data on Presentations.ai?',
#   'answer': 'We adhere to the terms of OpenAI/Anthropic. Your data remains secure and is not used to train our models. For more information, please review our terms and privacy policy.'}]
